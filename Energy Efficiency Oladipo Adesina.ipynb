# %% [markdown]
# Name: Oladipo Adesina
# Hamoye student ID: 13ee1d91ee81f000

# %%
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv('energydata_complete.csv')
raw_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4    ...             T9   RH_9     T_out  \
# 0  19.79  44.730000  19.000000    ...      17.033333  45.53  6.600000
# 1  19.79  44.790000  19.000000    ...      17.066667  45.56  6.483333
# 2  19.79  44.933333  18.926667    ...      17.000000  45.50  6.366667
# 3  19.79  45.000000  18.890000    ...      17.000000  45.40  6.250000
# 4  19.79  45.000000  18.890000    ...      17.000000  45.40  6.133333
#
# ...

# %%
raw_data.reset_index(drop=True)
data = raw_data.set_index('date')
data.head()
# Out:
#                      Appliances  lights     T1       RH_1    T2       RH_2  \
# date
# 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#                         T3       RH_3         T4       RH_4    ...      \
# date                                                           ...
# 2016-01-11 17:00:00  19.79  44.730000  19.000000  45.566667    ...
# 2016-01-11 17:10:00  19.79  44.790000  19.000000  45.992500    ...
# 2016-01-11 17:20:00  19.79  44.933333  18.926667  45.890000    ...
# 2016-01-11 17:30:00  19.79  45.000000  18.890000  45.723333    ...
# 2016-01-11 17:40:00  19.79  45.000000  18.890000  45.530000    ...
#
# ...

# %% [markdown]
# ### Question 12

# %%
from sklearn.linear_model import LinearRegression

# %%
x = data['T2'].values.reshape(-1,1)
y = data['T6'].values.reshape(-1,1)

reg = LinearRegression()
reg.fit(x,y)
np.round(reg.score(x,y), 2)
# Out:
# 0.64

# %%
data_quiz = raw_data.drop(['date', 'lights'], axis = 1)
data_quiz.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5    ...             T9   RH_9     T_out  Press_mm_hg  \
# 0  45.566667  17.166667    ...      17.033333  45.53  6.600000        733.5
# 1  45.992500  17.166667    ...      17.066667  45.56  6.483333        733.6
# 2  45.890000  17.166667    ...      17.000000  45.50  6.366667        733.7
# 3  45.723333  17.166667    ...      17.000000  45.40  6.250000        733.8
# 4  45.530000  17.200000    ...      17.000000  45.40  6.133333        733.9
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

x1 = data_quiz.iloc[:, 1:]
y1 = data_quiz['Appliances']
scaler = MinMaxScaler()

x_scaled = scaler.fit_transform(x1)
x_scaled
# Out:
# array([[0.32734952, 0.56618659, 0.22534529, ..., 0.53846154, 0.26544891,
#         0.26544891],
#        [0.32734952, 0.54132648, 0.22534529, ..., 0.53393665, 0.37208289,
#         0.37208289],
#        [0.32734952, 0.53050179, 0.22534529, ..., 0.52941176, 0.57284766,
#         0.57284766],
#        ...,
#        [0.91974657, 0.53866618, 0.69265118, ..., 0.89894419, 0.58397859,
#         0.58397859],
#        [0.91974657, 0.54949087, 0.67705355, ..., 0.8974359 , 0.12637146,
#         0.12637146],
#        [0.91974657, 0.53875791, 0.66617051, ..., 0.8959276 , 0.68239057,
#         0.68239057]])

# %%
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x_scaled, y1, test_size = 0.3, random_state = 42)

reg1 = LinearRegression()
reg1.fit(x_train, y_train)
reg1.score(x_train, y_train)
# Out:
# 0.14471942308518748

# %%
y_pred = reg1.predict(x_test)

# %% [markdown]
# ### Question 13

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
np.round(mae, 2)
# Out:
# 53.64

# %% [markdown]
# ### Question 14

# %%
rss = np.sum(np.square(y_test-y_pred))
np.round(rss,2)
# Out:
# 51918501.21

# %% [markdown]
# ### Question 15

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
np.round(rmse,3)
# Out:
# 93.64

# %% [markdown]
# ### Question 16

# %%
from sklearn.metrics import r2_score
coef_deter = r2_score(y_test, y_pred)
np.round(coef_deter, 2)
# Out:
# 0.15

# %% [markdown]
# ### Question 17

# %%
df = pd.DataFrame({'Features': x1.columns.values, 'Weights': reg1.coef_})
df.sort_values('Weights', ascending=True)
# Out:
#        Features     Weights
# 3          RH_2 -488.666805
# 18        T_out -344.389845
# 2            T2 -252.710373
# 16           T9 -203.236627
# 15         RH_8 -168.627161
# 20       RH_out  -83.107599
# 13         RH_7  -47.736592
# 17         RH_9  -42.586339
# 8            T5  -16.752822
# 0            T1   -3.510725
# 24          rv1    0.824005
# 25          rv2    0.824005
# 19  Press_mm_hg    7.318079
# 12           T7   11.041091
# 22   Visibility   13.168072
# 9          RH_5   17.126194
# 7          RH_4   28.232781
# 6            T4   31.009668
# 21    Windspeed   31.225948
# 11         RH_6   40.712058
# 5          RH_3  102.771652
# 14           T8  109.134698
# 23    Tdewpoint  126.000776
# 10           T6  252.974652
# 4            T3  310.971037
# 1          RH_1  592.294862

# %% [markdown]
# ### Question 18

# %%
from sklearn.linear_model import Ridge

reg_ridge = Ridge(alpha=0.4)
reg_ridge.fit(x_train, y_train)

y_pred_ridge = reg_ridge.predict(x_test)

# %%
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))
print(rmse_ridge)
print(rmse)
# Out:
# 93.66122703951963
# 93.64046093998029

# %% [markdown]
# ### Question 19

# %%
from sklearn.linear_model import Lasso

reg_lasso = Lasso(alpha=0.001)
reg_lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
df_lasso = pd.DataFrame({'Features': x1.columns.values, 'Weights': reg_lasso.coef_})
df_lasso[df_lasso['Weights'] != 0]
# Out:
#        Features     Weights
# 0            T1   -4.147124
# 1          RH_1  590.599827
# 2            T2 -249.468798
# 3          RH_2 -484.565333
# 4            T3  310.210384
# 5          RH_3  102.204611
# 6            T4   30.345197
# 7          RH_4   27.445905
# 8            T5  -17.118723
# 9          RH_5   17.103321
# 10           T6  250.080979
# 11         RH_6   40.092883
# 12           T7   10.346809
# 13         RH_7  -47.389094
# 14           T8  108.883423
# 15         RH_8 -168.695476
# 16           T9 -202.502545
# 17         RH_9  -42.455100
# 18        T_out -332.571693
# 19  Press_mm_hg    7.282154
# 20       RH_out  -78.000385
# 21    Windspeed   31.389514
# 22   Visibility   13.078319
# 23    Tdewpoint  118.598030
# 24          rv1    1.631174

# %% [markdown]
# ### Question 20

# %%
y_pred_lasso = reg_lasso.predict(x_test)

rmse_lasso = np.sqrt(mean_squared_error(y_test, y_pred_lasso))
np.round(rmse_lasso, 3)
# Out:
# 93.641
